# %%
import pandas as pd 
df= pd.read_csv('stock_data.csv')
df
# Out:
#      Unnamed: 0          Adj Close        Adj Close.1        Adj Close.2  \
# 0           NaN       AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                NaN                NaN                NaN
# 2    2020-01-01  174.5393829345703  746.0272827148438  2640.764892578125
# 3    2020-01-02  181.9373779296875  754.2479248046875   2616.36962890625
# 4    2020-01-03   180.209716796875     740.2978515625   2575.33447265625
# ..          ...                ...                ...                ...
# 764  2023-01-23  495.3163146972656       930.78515625  3407.178466796875
# 765  2023-01-24   493.191162109375  908.3313598632812   3466.36962890625
# 766  2023-01-25  454.8883972167969  890.5179443359375   3495.42431640625
# 767  2023-01-27  376.0588684082031  871.9561157226562  3701.676513671875
# 768  2023-01-30  383.0274963378906  870.0599975585938  3611.784912109375
#
#             Adj Close.3         Adj Close.4         Adj Close.5  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Adj Close', 'Adj Close.1', 'Adj Close.2', 'Adj Close.3',
#        'Adj Close.4', 'Adj Close.5', 'Adj Close.6', 'Adj Close.7',
#        'Adj Close.8',
#        ...
#        'Volume.18', 'Volume.19', 'Volume.20', 'Volume.21', 'Volume.22',
#        'Volume.23', 'Volume.24', 'Volume.25', 'Volume.26', 'Volume.27'],
#       dtype='object', length=169)

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      Unnamed: 0          Adj Close        Adj Close.1        Adj Close.2  \
# 0           NaN       AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                NaN                NaN                NaN
# 2    2020-01-01  174.5393829345703  746.0272827148438  2640.764892578125
# 3    2020-01-02  181.9373779296875  754.2479248046875   2616.36962890625
# 4    2020-01-03   180.209716796875     740.2978515625   2575.33447265625
# ..          ...                ...                ...                ...
# 764  2023-01-23  495.3163146972656       930.78515625  3407.178466796875
# 765  2023-01-24   493.191162109375  908.3313598632812   3466.36962890625
# 766  2023-01-25  454.8883972167969  890.5179443359375   3495.42431640625
# 767  2023-01-27  376.0588684082031  871.9561157226562  3701.676513671875
# 768  2023-01-30  383.0274963378906  870.0599975585938  3611.784912109375
#
#             Adj Close.3         Adj Close.4         Adj Close.5  \
# ...

# %%
columns_to_drop = [
    'Adj Close', 'Adj Close.1', 'Adj Close.2', 'Adj Close.3', 'Adj Close.4',
    'Adj Close.5', 'Adj Close.6', 'Adj Close.7', 'Adj Close.8', 'Adj Close.9',
    'Adj Close.10', 'Adj Close.11', 'Adj Close.12', 'Adj Close.13', 'Adj Close.14',
    'Adj Close.15', 'Adj Close.16', 'Adj Close.17', 'Adj Close.18', 'Adj Close.19',
    'Adj Close.20', 'Adj Close.21', 'Adj Close.22', 'Adj Close.23', 'Adj Close.24',
    'Adj Close.25', 'Adj Close.26', 'Adj Close.27',
    'High', 'High.1', 'High.2', 'High.3', 'High.4', 'High.5', 'High.6', 'High.7',
    'High.8', 'High.9', 'High.10', 'High.11', 'High.12', 'High.13', 'High.14',
    'High.15', 'High.16', 'High.17', 'High.18', 'High.19', 'High.20', 'High.21',
    'High.22', 'High.23', 'High.24', 'High.25', 'High.26', 'High.27',
    'Low', 'Low.1', 'Low.2', 'Low.3', 'Low.4', 'Low.5', 'Low.6', 'Low.7',
    'Low.8', 'Low.9', 'Low.10', 'Low.11', 'Low.12', 'Low.13', 'Low.14',
    'Low.15', 'Low.16', 'Low.17', 'Low.18', 'Low.19', 'Low.20', 'Low.21',
    'Low.22', 'Low.23', 'Low.24', 'Low.25', 'Low.26', 'Low.27'
]

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# Display the modified DataFrame
df
# Out:
#      Unnamed: 0               Close            Close.1            Close.2  \
# 0           NaN        AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                 NaN                NaN                NaN
# 2    2020-01-01               197.0  748.7000122070312   3150.10009765625
# 3    2020-01-02  205.35000610351562  756.9500122070312             3121.0
# 4    2020-01-03  203.39999389648438  742.9500122070312  3072.050048828125
# ..          ...                 ...                ...                ...
# 764  2023-01-23   501.1000061035156  932.7000122070312  3623.550048828125
# 765  2023-01-24  498.95001220703125  910.2000122070312             3686.5
# 766  2023-01-25  460.20001220703125  892.3499755859375   3717.39990234375
# 767  2023-01-27  380.45001220703125             873.75            3936.75
# 768  2023-01-30               387.5  871.8499755859375   3841.14990234375
#
#                 Close.3             Close.4             Close.5  \
# ...

# %%
volume_data = df[['Unnamed: 0', 'Volume', 'Volume.1', 'Volume.2', 'Volume.3', 'Volume.4', 'Volume.5', 'Volume.6', 'Volume.7', 'Volume.8',
                 'Volume.9', 'Volume.10', 'Volume.11', 'Volume.12', 'Volume.13', 'Volume.14', 'Volume.15', 'Volume.16','Volume.17', 'Volume.18', 'Volume.19', 'Volume.20', 'Volume.21', 'Volume.22', 'Volume.23', 'Volume.24', 'Volume.25', 'Volume.26', 'Volume.27', ]]

volume_data.to_csv('new_data.csv', index=False)
data= pd.read_csv('vsd.csv')
data
# Out:
#      Unnamed: 0               Close            Close.1            Close.2  \
# 0           NaN        AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                 NaN                NaN                NaN
# 2    2020-01-01               197.0  748.7000122070312   3150.10009765625
# 3    2020-01-02  205.35000610351562  756.9500122070312             3121.0
# 4    2020-01-03  203.39999389648438  742.9500122070312  3072.050048828125
# ..          ...                 ...                ...                ...
# 764  2023-01-23   501.1000061035156  932.7000122070312  3623.550048828125
# 765  2023-01-24  498.95001220703125  910.2000122070312             3686.5
# 766  2023-01-25  460.20001220703125  892.3499755859375   3717.39990234375
# 767  2023-01-27  380.45001220703125             873.75            3936.75
# 768  2023-01-30               387.5  871.8499755859375   3841.14990234375
#
#                 Close.3             Close.4             Close.5  \
# ...

# %%
companies = [
    'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BHARTIARTL.NS', 'BPCL.NS',
    'CIPLA.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS',
    'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDEA.NS', 'ITC.NS', 'MARUTI.NS',
    'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SHREECEM.NS',
    'SUNPHARMA.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TECHM.NS',
    'ULTRACEMCO.NS', 'VEDL.NS', 'WIPRO.NS'
]

# Convert the columns to numeric type
data[companies] = data[companies].apply(pd.to_numeric, errors='coerce')

# Calculate the percentile change for each company's volume
for company in companies:
    data[f'{company} Percentile Change'] = data[company].pct_change() * 100

# Display the DataFrame with percentile change columns
data
# Out:
#           date  AMBUJACEM.NS  AXISBANK.NS  BAJAJ-AUTO.NS  BHARTIARTL.NS  \
# 0     1/1/2020       1459556      4917748         320021        5059995
# 1     1/2/2020       8633553      5156046         452413        4842142
# 2     1/3/2020       2007973      8489729         424311        5059594
# 3     1/6/2020       2119702      6356198         355754        7399981
# 4     1/7/2020       3557312      9103360         225535        4273646
# ..         ...           ...          ...            ...            ...
# 762  1/23/2023       4154237      5236124         173482        2685320
# 763  1/24/2023       2166537     18527897         212778        5012125
# 764  1/25/2023      33646469     11921748         375571        6560514
# 765  1/27/2023      91035714     17300736        2375899        6745926
# 766  1/30/2023      71717149     21233998         654472        5420851
#
#       BPCL.NS  CIPLA.NS  DRREDDY.NS  HDFCBANK.NS  HEROMOTOCO.NS  HINDALCO.NS  \
# ...

# %%
# Define a dictionary to map companies to sectors
company_to_sector = {
    'HDFCBANK.NS': 'Banking and Finance',
    'ICICIBANK.NS': 'Banking and Finance',
    'AXISBANK.NS': 'Banking and Finance',
    'MARUTI.NS': 'Automobile',
    'BAJAJ-AUTO.NS': 'Automobile',
    'HEROMOTOCO.NS': 'Automobile',
    'TCS.NS': 'Information Technology',
    'WIPRO.NS': 'Information Technology',
    'TECHM.NS': 'Information Technology',
    'ONGC.NS': 'Energy',
    'BPCL.NS': 'Energy',
    'SUNPHARMA.NS': 'Pharmaceuticals',
    'DRREDDY.NS': 'Pharmaceuticals',
    'CIPLA.NS': 'Pharmaceuticals',
    'HINDUNILVR.NS': 'Consumer Goods',
    'ITC.NS': 'Consumer Goods',
    'NESTLEIND.NS': 'Consumer Goods',
    'BHARTIARTL.NS': 'Telecommunications',
    'IDEA.NS': 'Telecommunications',
    'NTPC.NS': 'Utilities',
    'POWERGRID.NS': 'Utilities',
    'TATAPOWER.NS': 'Utilities',
    'ULTRACEMCO.NS': 'Cement',
    'AMBUJACEM.NS': 'Cement',
    'SHREECEM.NS': 'Cement',
    'TATASTEEL.NS': 'Metals and Mining',
    'HINDALCO.NS': 'Metals and Mining',
    'VEDL.NS': 'Metals and Mining'
}

data = data.transpose()

# Create a new 'Sector' column by mapping company names to sectors
data['Sector'] = data.index.map(company_to_sector)

# Transpose the DataFrame back to its original format
data = data.transpose()

nd= data.loc[data.index[-1]] 
df = pd.DataFrame(nd)
df
# Out:
#                                                  Sector
# date                                                NaN
# AMBUJACEM.NS                                     Cement
# AXISBANK.NS                         Banking and Finance
# BAJAJ-AUTO.NS                                Automobile
# BHARTIARTL.NS                        Telecommunications
# BPCL.NS                                          Energy
# CIPLA.NS                                Pharmaceuticals
# DRREDDY.NS                              Pharmaceuticals
# HDFCBANK.NS                         Banking and Finance
# HEROMOTOCO.NS                                Automobile
# HINDALCO.NS                           Metals and Mining
# HINDUNILVR.NS                            Consumer Goods
# ICICIBANK.NS                        Banking and Finance
# IDEA.NS                              Telecommunications
# ITC.NS                                   Consumer Goods
# MARUTI.NS                                    Automobile
# ...

# %%
data
# Out:
#              date AMBUJACEM.NS          AXISBANK.NS BAJAJ-AUTO.NS  \
# 0        1/1/2020      1459556              4917748        320021
# 1        1/2/2020      8633553              5156046        452413
# 2        1/3/2020      2007973              8489729        424311
# 3        1/6/2020      2119702              6356198        355754
# 4        1/7/2020      3557312              9103360        225535
# ...           ...          ...                  ...           ...
# 763     1/24/2023      2166537             18527897        212778
# 764     1/25/2023     33646469             11921748        375571
# 765     1/27/2023     91035714             17300736       2375899
# 766     1/30/2023     71717149             21233998        654472
# Sector        NaN       Cement  Banking and Finance    Automobile
#
#              BHARTIARTL.NS   BPCL.NS         CIPLA.NS       DRREDDY.NS  \
# 0                  5059995   2383296          1316812           154779
# ...

# %%
company_to_sector = {
    'HDFCBANK.NS Percentile Change': 'Banking and Finance',
    'ICICIBANK.NS Percentile Change': 'Banking and Finance',
    'AXISBANK.NS Percentile Change': 'Banking and Finance',
    'MARUTI.NS Percentile Change': 'Automobile',
    'BAJAJ-AUTO.NS Percentile Change': 'Automobile',
    'HEROMOTOCO.NS Percentile Change': 'Automobile',
    'TCS.NS': 'Information Technology Percentile Change',
    'WIPRO.NS Percentile Change': 'Information Technology',
    'TECHM.NS Percentile Change': 'Information Technology',
    'ONGC.NS Percentile Change': 'Energy',
    'BPCL.NS Percentile Change': 'Energy',
    'SUNPHARMA.NS Percentile Change': 'Pharmaceuticals',
    'DRREDDY.NS Percentile Change': 'Pharmaceuticals',
    'CIPLA.NS Percentile Change': 'Pharmaceuticals',
    'HINDUNILVR.NS Percentile Change': 'Consumer Goods',
    'ITC.NS Percentile Change': 'Consumer Goods',
    'NESTLEIND.NS Percentile Change': 'Consumer Goods',
    'BHARTIARTL.NS Percentile Change': 'Telecommunications',
    'IDEA.NS Percentile Change': 'Telecommunications',
    'NTPC.NS Percentile Change': 'Utilities',
    'POWERGRID.NS Percentile Change': 'Utilities',
    'TATAPOWER.NS Percentile Change': 'Utilities',
    'ULTRACEMCO.NS Percentile Change': 'Cement',
    'AMBUJACEM.NS Percentile Change': 'Cement',
    'SHREECEM.NS Percentile Change': 'Cement',
    'TATASTEEL.NS Percentile Change': 'Metals and Mining',
    'HINDALCO.NS Percentile Change': 'Metals and Mining',
    'VEDL.NS Percentile Change': 'Metals and Mining'
}

data = data.transpose()

# Create a new 'Sector' column by mapping company names to sectors
data['Sector'] = data.index.map(company_to_sector)

# Transpose the DataFrame back to its original format
data = data.transpose()

nd= data.loc[data.index[-1]] 
df = pd.DataFrame(nd)
df
# Out:
#                                                                    Sector
# date                                                                  NaN
# AMBUJACEM.NS                                                          NaN
# AXISBANK.NS                                                           NaN
# BAJAJ-AUTO.NS                                                         NaN
# BHARTIARTL.NS                                                         NaN
# BPCL.NS                                                               NaN
# CIPLA.NS                                                              NaN
# DRREDDY.NS                                                            NaN
# HDFCBANK.NS                                                           NaN
# HEROMOTOCO.NS                                                         NaN
# HINDALCO.NS                                                           NaN
# HINDUNILVR.NS                                                         NaN
# ...

# %%
data
# Out:
#              date AMBUJACEM.NS AXISBANK.NS BAJAJ-AUTO.NS BHARTIARTL.NS  \
# 0        1/1/2020      1459556     4917748        320021       5059995
# 1        1/2/2020      8633553     5156046        452413       4842142
# 2        1/3/2020      2007973     8489729        424311       5059594
# 3        1/6/2020      2119702     6356198        355754       7399981
# 4        1/7/2020      3557312     9103360        225535       4273646
# ...           ...          ...         ...           ...           ...
# 763     1/24/2023      2166537    18527897        212778       5012125
# 764     1/25/2023     33646469    11921748        375571       6560514
# 765     1/27/2023     91035714    17300736       2375899       6745926
# 766     1/30/2023     71717149    21233998        654472       5420851
# Sector        NaN          NaN         NaN           NaN           NaN
#
#          BPCL.NS CIPLA.NS DRREDDY.NS HDFCBANK.NS HEROMOTOCO.NS HINDALCO.NS  \
# ...

# %%
# List of company columns to drop
companies_to_drop = [
    'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BHARTIARTL.NS', 'BPCL.NS',
    'CIPLA.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS',
    'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDEA.NS', 'ITC.NS', 'MARUTI.NS',
    'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SHREECEM.NS',
    'SUNPHARMA.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TECHM.NS',
    'ULTRACEMCO.NS', 'VEDL.NS', 'WIPRO.NS'
]

# Drop the specified columns
data.drop(columns=companies_to_drop, inplace=True)

# Display the DataFrame without the dropped columns
data = data.tail(-1)
data
# Out:
#              date AMBUJACEM.NS Percentile Change  \
# 1        1/2/2020                     491.519133
# 2        1/3/2020                     -76.742217
# 3        1/6/2020                       5.564268
# 4        1/7/2020                      67.821326
# 5        1/8/2020                      38.962621
# ...           ...                            ...
# 763     1/24/2023                     -47.847535
# 764     1/25/2023                    1453.006895
# 765     1/27/2023                     170.565431
# 766     1/30/2023                     -21.220864
# Sector        NaN                         Cement
#
#        AXISBANK.NS Percentile Change BAJAJ-AUTO.NS Percentile Change  \
# 1                           4.845673                       41.369785
# 2                          64.655804                       -6.211581
# 3                         -25.130731                      -16.157253
# 4                          43.220208                      -36.603664
# ...

# %%
data = data.iloc[1:]

# Set the last row as the new header
data.columns = data.iloc[-1]

# Remove the last row (old header)
data = data.iloc[:-1]

# Reset the index
data.reset_index(drop=True, inplace=True)
data
# Out:
# Sector        NaN       Cement Banking and Finance  Automobile  \
# 0        1/3/2020   -76.742217           64.655804   -6.211581
# 1        1/6/2020     5.564268          -25.130731  -16.157253
# 2        1/7/2020    67.821326           43.220208  -36.603664
# 3        1/8/2020    38.962621           -1.429637   74.524575
# 4        1/9/2020    12.027227          -15.750899  -15.391983
# ..            ...          ...                 ...         ...
# 760     1/23/2023    56.377261           16.065311   -9.343074
# 761     1/24/2023   -47.847535           253.84756   22.651341
# 762     1/25/2023  1453.006895          -35.655147    76.50838
# 763     1/27/2023   170.565431           45.119122  532.609813
# 764     1/30/2023   -21.220864           22.734651  -72.453711
#
# Sector Telecommunications      Energy Pharmaceuticals Pharmaceuticals  \
# 0                4.490822  252.617275       60.180776       15.342116
# ...

# %%
sectors_to_average = ['Cement', 'Banking and Finance', 'Automobile', 'Telecommunications',
                      'Energy', 'Pharmaceuticals', 'Utilities', 'Metals and Mining',
                      'Consumer Goods', 'Information Technology']

# Create an empty DataFrame to store the averages
averages_df = pd.DataFrame()

# Calculate the average for each sector and add it to the new DataFrame
for sector in sectors_to_average:
    averages_df[sector] = data[sector].mean(axis=1)

averages_df
# Out:
#          Cement  Banking and Finance  Automobile  Telecommunications  \
# 0    -57.731361            45.004986   -4.630914            9.895390
# 1      4.438692             1.942190    9.795362           15.785692
# 2    102.432216            35.630293  -19.450352           -6.421013
# 3     39.162706            -8.171808   34.958112          255.456692
# 4    -20.518739            -4.621809    2.694743           22.685835
# ..          ...                  ...         ...                 ...
# 760   97.128320            35.251666   17.951965           28.294839
# 761  -26.100964            94.585710   35.180911           41.949849
# 762  474.459015           -15.706979   86.861185           14.072590
# 763   68.607087           116.869710  176.130641           18.636596
# 764   -2.368621           -11.081914  -11.347373           -0.912249
#
#          Energy  Pharmaceuticals  Utilities  Metals and Mining  \
# 0    405.958040        61.038104  -1.790488         -37.583529
# ...

# %%
data.to_csv('new_data.csv', index=False)
df= pd.read_csv('Volume.csv')
df
# Out:
#           Date       Cement  Banking and Finance  Automobile  \
# 0     1/3/2020   -76.742217            64.655804   -6.211581
# 1     1/6/2020     5.564268           -25.130731  -16.157253
# 2     1/7/2020    67.821326            43.220208  -36.603664
# 3     1/8/2020    38.962621            -1.429637   74.524575
# 4     1/9/2020    12.027227           -15.750899  -15.391983
# ..         ...          ...                  ...         ...
# 760  1/23/2023    56.377261            16.065311   -9.343074
# 761  1/24/2023   -47.847535           253.847560   22.651341
# 762  1/25/2023  1453.006895           -35.655147   76.508380
# 763  1/27/2023   170.565431            45.119122  532.609813
# 764  1/30/2023   -21.220864            22.734651  -72.453711
#
#      Telecommunications      Energy  Pharmaceuticals  Pharmaceuticals.1  \
# 0              4.490822  252.617275        60.180776          15.342116
# 1             46.256419  -32.322805       -33.332431           3.788754
# ...

# %%
averages_df['date'] = df['Date']

# %%
averages_df
# Out:
#                Cement  Banking and Finance  Automobile  Telecommunications  \
# date
# 1/3/2020   -57.731361            45.004986   -4.630914            9.895390
# 1/6/2020     4.438692             1.942190    9.795362           15.785692
# 1/7/2020   102.432216            35.630293  -19.450352           -6.421013
# 1/8/2020    39.162706            -8.171808   34.958112          255.456692
# 1/9/2020   -20.518739            -4.621809    2.694743           22.685835
# ...               ...                  ...         ...                 ...
# 1/23/2023   97.128320            35.251666   17.951965           28.294839
# 1/24/2023  -26.100964            94.585710   35.180911           41.949849
# 1/25/2023  474.459015           -15.706979   86.861185           14.072590
# 1/27/2023   68.607087           116.869710  176.130641           18.636596
# 1/30/2023   -2.368621           -11.081914  -11.347373           -0.912249
#
# ...

# %%
averages_df.to_csv('new_Vol.csv', index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Create a correlation matrix and heatmap
correlation_matrix =averages_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
averages_df
# Out:
#                Cement  Banking and Finance  Automobile  Telecommunications  \
# date
# 1/3/2020   -57.731361            45.004986   -4.630914            9.895390
# 1/6/2020     4.438692             1.942190    9.795362           15.785692
# 1/7/2020   102.432216            35.630293  -19.450352           -6.421013
# 1/8/2020    39.162706            -8.171808   34.958112          255.456692
# 1/9/2020   -20.518739            -4.621809    2.694743           22.685835
# ...               ...                  ...         ...                 ...
# 1/23/2023   97.128320            35.251666   17.951965           28.294839
# 1/24/2023  -26.100964            94.585710   35.180911           41.949849
# 1/25/2023  474.459015           -15.706979   86.861185           14.072590
# 1/27/2023   68.607087           116.869710  176.130641           18.636596
# 1/30/2023   -2.368621           -11.081914  -11.347373           -0.912249
#
# ...

# %% [markdown]
# From the correlation matrix, it is evident that the telecommunications sector exhibits very low or negligible correlations with all other sectors. This indicates that the telecommunications sector operates relatively independently and does not appear to have a significant influence or dependence on the performance of other sectors in the dataset.

# %%
# Create subplots for each sector
sectors = df_selected.columns
fig, axes = plt.subplots(nrows=len(sectors), ncols=1, figsize=(10, 2*len(sectors)), sharex=True)

for i, sector in enumerate(sectors):
    axes[i].plot(df_selected.index, df_selected[sector])
    axes[i].set_title(sector)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.stackplot(df_selected.index, df_selected.T, labels=df_selected.columns, alpha=0.7)
plt.legend(loc='upper left')
plt.title('Stacked Area Plot of Sector Contributions')
plt.show()

# %%
import pandas as pd 
df= pd.read_csv('stock_data.csv')
df
# Out:
#      Unnamed: 0          Adj Close        Adj Close.1        Adj Close.2  \
# 0           NaN       AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                NaN                NaN                NaN
# 2    2020-01-01  174.5393829345703  746.0272827148438  2640.764892578125
# 3    2020-01-02  181.9373779296875  754.2479248046875   2616.36962890625
# 4    2020-01-03   180.209716796875     740.2978515625   2575.33447265625
# ..          ...                ...                ...                ...
# 764  2023-01-23  495.3163146972656       930.78515625  3407.178466796875
# 765  2023-01-24   493.191162109375  908.3313598632812   3466.36962890625
# 766  2023-01-25  454.8883972167969  890.5179443359375   3495.42431640625
# 767  2023-01-27  376.0588684082031  871.9561157226562  3701.676513671875
# 768  2023-01-30  383.0274963378906  870.0599975585938  3611.784912109375
#
#             Adj Close.3         Adj Close.4         Adj Close.5  \
# ...

# %%
CPrice_data = df[['Unnamed: 0', 'Close', 'Close.1', 'Close.2', 'Close.3', 'Close.4', 'Close.5', 'Close.6', 'Close.7', 'Close.8', 'Close.9', 'Close.10', 'Close.11', 'Close.12', 'Close.13', 'Close.14', 'Close.15', 'Close.16', 'Close.17', 'Close.18', 'Close.19', 'Close.20', 'Close.21', 'Close.22', 'Close.23', 'Close.24', 'Close.25', 'Close.26', 'Close.27' ]]

CPrice_data.to_csv('CPrice_data.csv', index=False)
CPrice_data
# Out:
#      Unnamed: 0               Close            Close.1            Close.2  \
# 0           NaN        AMBUJACEM.NS        AXISBANK.NS      BAJAJ-AUTO.NS
# 1          Date                 NaN                NaN                NaN
# 2    2020-01-01               197.0  748.7000122070312   3150.10009765625
# 3    2020-01-02  205.35000610351562  756.9500122070312             3121.0
# 4    2020-01-03  203.39999389648438  742.9500122070312  3072.050048828125
# ..          ...                 ...                ...                ...
# 764  2023-01-23   501.1000061035156  932.7000122070312  3623.550048828125
# 765  2023-01-24  498.95001220703125  910.2000122070312             3686.5
# 766  2023-01-25  460.20001220703125  892.3499755859375   3717.39990234375
# 767  2023-01-27  380.45001220703125             873.75            3936.75
# 768  2023-01-30               387.5  871.8499755859375   3841.14990234375
#
#                 Close.3             Close.4             Close.5  \
# ...

# %%
df= pd.read_csv('CPrice_data.csv')
df
# Out:
#           Date  AMBUJACEM.NS  AXISBANK.NS  BAJAJ-AUTO.NS  BHARTIARTL.NS  \
# 0     1/1/2020    197.000000   748.700012    3150.100098     453.299988
# 1     1/2/2020    205.350006   756.950012    3121.000000     455.200012
# 2     1/3/2020    203.399994   742.950012    3072.050049     455.100006
# 3     1/6/2020    196.899994   723.250000    3037.649902     449.649994
# 4     1/7/2020    199.000000   725.750000    3037.949951     445.100006
# ..         ...           ...          ...            ...            ...
# 762  1/23/2023    501.100006   932.700012    3623.550049     772.700012
# 763  1/24/2023    498.950012   910.200012    3686.500000     775.650024
# 764  1/25/2023    460.200012   892.349976    3717.399902     776.500000
# 765  1/27/2023    380.450012   873.750000    3936.750000     774.500000
# 766  1/30/2023    387.500000   871.849976    3841.149902     770.200012
#
#         BPCL.NS     CIPLA.NS   DRREDDY.NS  HDFCBANK.NS  HEROMOTOCO.NS  \
# ...

# %%
companies = [
    'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BHARTIARTL.NS', 'BPCL.NS',
    'CIPLA.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS',
    'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDEA.NS', 'ITC.NS', 'MARUTI.NS',
    'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SHREECEM.NS',
    'SUNPHARMA.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TECHM.NS',
    'ULTRACEMCO.NS', 'VEDL.NS', 'WIPRO.NS'
]

# Convert the columns to numeric type
df[companies] = df[companies].apply(pd.to_numeric, errors='coerce')

# Calculate the percentile change for each company's price
for company in companies:
    df[f'{company} Percentile Change'] = df[company].pct_change() * 100

# Display the DataFrame with percentile change columns
df
# Out:
#           Date  AMBUJACEM.NS  AXISBANK.NS  BAJAJ-AUTO.NS  BHARTIARTL.NS  \
# 0     1/1/2020    197.000000   748.700012    3150.100098     453.299988
# 1     1/2/2020    205.350006   756.950012    3121.000000     455.200012
# 2     1/3/2020    203.399994   742.950012    3072.050049     455.100006
# 3     1/6/2020    196.899994   723.250000    3037.649902     449.649994
# 4     1/7/2020    199.000000   725.750000    3037.949951     445.100006
# ..         ...           ...          ...            ...            ...
# 762  1/23/2023    501.100006   932.700012    3623.550049     772.700012
# 763  1/24/2023    498.950012   910.200012    3686.500000     775.650024
# 764  1/25/2023    460.200012   892.349976    3717.399902     776.500000
# 765  1/27/2023    380.450012   873.750000    3936.750000     774.500000
# 766  1/30/2023    387.500000   871.849976    3841.149902     770.200012
#
#         BPCL.NS     CIPLA.NS   DRREDDY.NS  HDFCBANK.NS  HEROMOTOCO.NS  \
# ...

# %%
company_to_sector = {
    'HDFCBANK.NS Percentile Change': 'Banking and Finance',
    'ICICIBANK.NS Percentile Change': 'Banking and Finance',
    'AXISBANK.NS Percentile Change': 'Banking and Finance',
    'MARUTI.NS Percentile Change': 'Automobile',
    'BAJAJ-AUTO.NS Percentile Change': 'Automobile',
    'HEROMOTOCO.NS Percentile Change': 'Automobile',
    'TCS.NS': 'Information Technology Percentile Change',
    'WIPRO.NS Percentile Change': 'Information Technology',
    'TECHM.NS Percentile Change': 'Information Technology',
    'ONGC.NS Percentile Change': 'Energy',
    'BPCL.NS Percentile Change': 'Energy',
    'SUNPHARMA.NS Percentile Change': 'Pharmaceuticals',
    'DRREDDY.NS Percentile Change': 'Pharmaceuticals',
    'CIPLA.NS Percentile Change': 'Pharmaceuticals',
    'HINDUNILVR.NS Percentile Change': 'Consumer Goods',
    'ITC.NS Percentile Change': 'Consumer Goods',
    'NESTLEIND.NS Percentile Change': 'Consumer Goods',
    'BHARTIARTL.NS Percentile Change': 'Telecommunications',
    'IDEA.NS Percentile Change': 'Telecommunications',
    'NTPC.NS Percentile Change': 'Utilities',
    'POWERGRID.NS Percentile Change': 'Utilities',
    'TATAPOWER.NS Percentile Change': 'Utilities',
    'ULTRACEMCO.NS Percentile Change': 'Cement',
    'AMBUJACEM.NS Percentile Change': 'Cement',
    'SHREECEM.NS Percentile Change': 'Cement',
    'TATASTEEL.NS Percentile Change': 'Metals and Mining',
    'HINDALCO.NS Percentile Change': 'Metals and Mining',
    'VEDL.NS Percentile Change': 'Metals and Mining'
}

df = df.transpose()

# Create a new 'Sector' column by mapping company names to sectors
df['Sector'] = df.index.map(company_to_sector)

# Transpose the DataFrame back to its original format
df = df.transpose()

# nd= df.loc[df.index[-1]] 
# df = pd.DataFrame(nd)
df
# Out:
#              Date AMBUJACEM.NS AXISBANK.NS BAJAJ-AUTO.NS BHARTIARTL.NS  \
# 0        1/1/2020        197.0  748.700012   3150.100098    453.299988
# 1        1/2/2020   205.350006  756.950012        3121.0    455.200012
# 2        1/3/2020   203.399994  742.950012   3072.050049    455.100006
# 3        1/6/2020   196.899994      723.25   3037.649902    449.649994
# 4        1/7/2020        199.0      725.75   3037.949951    445.100006
# ...           ...          ...         ...           ...           ...
# 763     1/24/2023   498.950012  910.200012        3686.5    775.650024
# 764     1/25/2023   460.200012  892.349976   3717.399902         776.5
# 765     1/27/2023   380.450012      873.75       3936.75         774.5
# 766     1/30/2023        387.5  871.849976   3841.149902    770.200012
# Sector        NaN          NaN         NaN           NaN           NaN
#
#            BPCL.NS     CIPLA.NS   DRREDDY.NS  HDFCBANK.NS HEROMOTOCO.NS  \
# ...

# %%
# List of company columns to drop
companies_to_drop = [
    'AMBUJACEM.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BHARTIARTL.NS', 'BPCL.NS',
    'CIPLA.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS',
    'HINDUNILVR.NS', 'ICICIBANK.NS', 'IDEA.NS', 'ITC.NS', 'MARUTI.NS',
    'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SHREECEM.NS',
    'SUNPHARMA.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TCS.NS', 'TECHM.NS',
    'ULTRACEMCO.NS', 'VEDL.NS', 'WIPRO.NS'
]

# Drop the specified columns
df.drop(columns=companies_to_drop, inplace=True)

# Display the DataFrame without the dropped columns
df = df.tail(-1)
df
# Out:
#              Date AMBUJACEM.NS Percentile Change  \
# 1        1/2/2020                       4.238582
# 2        1/3/2020                      -0.949604
# 3        1/6/2020                      -3.195674
# 4        1/7/2020                       1.066534
# 5        1/8/2020                       1.331655
# ...           ...                            ...
# 763     1/24/2023                      -0.429055
# 764     1/25/2023                      -7.766309
# 765     1/27/2023                     -17.329422
# 766     1/30/2023                       1.853065
# Sector        NaN                         Cement
#
#        AXISBANK.NS Percentile Change BAJAJ-AUTO.NS Percentile Change  \
# 1                            1.10191                       -0.923783
# 2                          -1.849528                       -1.568406
# 3                          -2.651593                       -1.119778
# 4                           0.345662                        0.009878
# ...

# %%
df = df.iloc[1:]

# Set the last row as the new header
df.columns = df.iloc[-1]

# Remove the last row (old header)
df = df.iloc[:-1]

# Reset the index
df.reset_index(drop=True, inplace=True)
df
# Out:
# Sector        NaN     Cement Banking and Finance Automobile  \
# 0        1/3/2020  -0.949604           -1.849528  -1.568406
# 1        1/6/2020  -3.195674           -2.651593  -1.119778
# 2        1/7/2020   1.066534            0.345662   0.009878
# 3        1/8/2020   1.331655           -0.172236   0.701132
# 4        1/9/2020   3.124227            2.532778   0.864589
# ..            ...        ...                 ...        ...
# 760     1/23/2023  -3.215837            0.231049   1.421875
# 761     1/24/2023  -0.429055           -2.412351   1.737245
# 762     1/25/2023  -7.766309           -1.961111   0.838191
# 763     1/27/2023 -17.329422           -2.084381   5.900632
# 764     1/30/2023   1.853065           -0.217456  -2.428402
#
# Sector Telecommunications    Energy Pharmaceuticals Pharmaceuticals  \
# 0                -0.02197 -0.830682       -0.749733        0.663199
# 1               -1.197542 -2.967943       -0.680926       -0.175103
# ...

# %%
sectors_to_average = ['Cement', 'Banking and Finance', 'Automobile', 'Telecommunications',
                      'Energy', 'Pharmaceuticals', 'Utilities', 'Metals and Mining',
                      'Consumer Goods', 'Information Technology']

# Create an empty DataFrame to store the averages
averages_df = pd.DataFrame()

# Calculate the average for each sector and add it to the new DataFrame
for sector in sectors_to_average:
    averages_df[sector] = df[sector].mean(axis=1)

averages_df
# Out:
#        Cement  Banking and Finance  Automobile  Telecommunications    Energy  \
# 0   -0.690100            -1.199771   -0.826811           -0.010985 -0.259154
# 1   -1.647133            -2.418706   -2.226522           -1.418442 -2.340335
# 2    2.459302             0.465502   -0.131949           -0.505948 -1.066611
# 3    1.773439             0.049758   -0.380227            5.711263 -1.033821
# 4    2.128739             2.507804    1.733394           -1.786867  1.259115
# ..        ...                  ...         ...                 ...       ...
# 760 -4.481461             0.372558    0.725958           -0.839705  0.716540
# 761 -0.958148            -0.394167    1.662229            0.190890 -0.158605
# 762 -3.781357            -2.166214    0.763796           -2.072870 -0.216645
# 763 -6.093932            -2.843831    1.205363           -2.721375 -3.045090
# 764  2.513187             0.150450   -0.918555            2.847403 -1.146675
#
# ...

# %%
df1= pd.read_csv('CPrice_data.csv')
df1
# Out:
#           Date  AMBUJACEM.NS  AXISBANK.NS  BAJAJ-AUTO.NS  BHARTIARTL.NS  \
# 0     1/1/2020    197.000000   748.700012    3150.100098     453.299988
# 1     1/2/2020    205.350006   756.950012    3121.000000     455.200012
# 2     1/3/2020    203.399994   742.950012    3072.050049     455.100006
# 3     1/6/2020    196.899994   723.250000    3037.649902     449.649994
# 4     1/7/2020    199.000000   725.750000    3037.949951     445.100006
# ..         ...           ...          ...            ...            ...
# 762  1/23/2023    501.100006   932.700012    3623.550049     772.700012
# 763  1/24/2023    498.950012   910.200012    3686.500000     775.650024
# 764  1/25/2023    460.200012   892.349976    3717.399902     776.500000
# 765  1/27/2023    380.450012   873.750000    3936.750000     774.500000
# 766  1/30/2023    387.500000   871.849976    3841.149902     770.200012
#
#         BPCL.NS     CIPLA.NS   DRREDDY.NS  HDFCBANK.NS  HEROMOTOCO.NS  \
# ...

# %%
averages_df['Date']=df1['Date']
averages_df
# Out:
#        Cement  Banking and Finance  Automobile  Telecommunications    Energy  \
# 0   -0.690100            -1.199771   -0.826811           -0.010985 -0.259154
# 1   -1.647133            -2.418706   -2.226522           -1.418442 -2.340335
# 2    2.459302             0.465502   -0.131949           -0.505948 -1.066611
# 3    1.773439             0.049758   -0.380227            5.711263 -1.033821
# 4    2.128739             2.507804    1.733394           -1.786867  1.259115
# ..        ...                  ...         ...                 ...       ...
# 760 -4.481461             0.372558    0.725958           -0.839705  0.716540
# 761 -0.958148            -0.394167    1.662229            0.190890 -0.158605
# 762 -3.781357            -2.166214    0.763796           -2.072870 -0.216645
# 763 -6.093932            -2.843831    1.205363           -2.721375 -3.045090
# 764  2.513187             0.150450   -0.918555            2.847403 -1.146675
#
# ...

# %%
averages_df.to_csv('CPrice_sd.csv', index=False)
